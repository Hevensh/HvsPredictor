# %% [markdown]
# <a href="https://colab.research.google.com/github/Hevensh/HvsPredictor/blob/main/unpredictable_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test of Hevensh's New Loss Function

# %% [markdown]
# test on the data in 482 points. compare with mse.

# %%
# !git clone https://github.com/Hevensh/HvsPredictor.git
# Out:
# Cloning into 'HvsPredictor'...
# remote: Enumerating objects: 111, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 111 (delta 57), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (111/111), 594.57 KiB | 11.89 MiB/s, done.
# Resolving deltas: 100% (57/57), done.

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('HvsPredictor/price_data.csv')
data = np.array(data)
data = np.log(data)
data.resize([482,])

# %%
from HvsPredictor import MyPredictor as hvs
import IPython.display

md1 = hvs.MyPredictor(data,metrics ='profit')
md1.deTrend()
md1.Options_set()
md1.compile_and_fit()
IPython.display.clear_output()

# %%
md2 = hvs.MyPredictor(data,metrics='profit')
md2.deTrend()
md2.Options_set(loss_func='mse')
md2.compile_and_fit()
IPython.display.clear_output()

# %%
md1.result_plot()

# %%
md2.result_plot()

# %%
md1.profit(400)
md2.profit(400)
md1
# Out:
# The model uses <HvsPredictor.MyPredictor.CautiousLoss object at 0x7f35457cb0d0>
# Backtest from date 400
# Total profit is : 1.3173%
# Daily profit is : 0.0161%
# Maximum drawdown is : -6.9210%

# %%
md2
# Out:
# The model uses mse
# Backtest from date 400
# Total profit is : 0.3823%
# Daily profit is : 0.0047%
# Maximum drawdown is : -19.3478%
