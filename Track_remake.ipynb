# %% [markdown]
# <a href="https://colab.research.google.com/github/Hevensh/HvsPredictor/blob/main/Track_remake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test of Hevensh's New Loss Function

# %% [markdown]
# test on the data in 482 points. compare with mse.

# %%
# !git clone https://github.com/Hevensh/HvsPredictor.git
# Out:
# Cloning into 'HvsPredictor'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 61 (delta 30), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (61/61), done.

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('HvsPredictor/price_data.csv')
data = np.array(data)
data = np.log(data)
data.resize([482,])

# %%
from HvsPredictor import MyPredictor as hvs
import IPython.display

md1 = hvs.MyPredictor(data)
md1.deTrend()
md1.Options_set()
md1.compile_and_fit()
IPython.display.clear_output()

# %%
md2 = hvs.MyPredictor(data)
md2.deTrend()
md2.Options_set(loss_func='mse')
md2.compile_and_fit()
IPython.display.clear_output()

# %%
md1.result_plot()

# %%
md2.result_plot()

# %%
md1.profit(400)
md2.profit(400)
md1
# Out:
# The model uses <HvsPredictor.MyPredictor.MyLoss object at 0x7f086364ee90>
# Backtest from date 400
# Total profit is : 0.8043%
# Daily profit is : 0.0098%
# Callback rate is : -4.5171%

# %%
md2
# Out:
# The model uses mse
# Backtest from date 400
# Total profit is : 4.7051%
# Daily profit is : 0.0574%
# Callback rate is : -13.1869%
